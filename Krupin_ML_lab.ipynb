# %% [markdown]
# # Быстрый старт в анализ данных
#
# **с помощью `Pandas` и `Scikit-learn`,**
# **а также `numpy` и `matplotlib`**
#
# - `numpy` – матричные операции
# - `matplotlib` – научная графика
# - `pandas` – таблицы (DataFrame) для анализа данных
# - `scikit-learn` – алгоритмы машинного обучения

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('listings.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#             id                                               name    host_id  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2     266763
# 1        50646                    Pleasant Room along Bukit Timah     227796
# 2        56334                                        COZICOMFORT     266763
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO     367042
# 4        71896                    B&B  Room 1 near Airport & EXPO     367042
# 5        71903                         Room 2-near Airport & EXPO     367042
# 6        71907                   3rd level Jumbo room 5 near EXPO     367042
# 7       241503             Long stay at The Breezy East "Leopard"    1017645
# 8       241508            Long stay at The Breezy East "Plumeria"    1017645
# 9       241510            Long stay at The Breezy East "Red Palm"    1017645
# 10      275343  Conveniently located City Room!( (Phone number...    1439258
# ...

# %%
print(data)
# Out:
#             id                                               name    host_id  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2     266763
# 1        50646                    Pleasant Room along Bukit Timah     227796
# 2        56334                                        COZICOMFORT     266763
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO     367042
# 4        71896                    B&B  Room 1 near Airport & EXPO     367042
# 5        71903                         Room 2-near Airport & EXPO     367042
# 6        71907                   3rd level Jumbo room 5 near EXPO     367042
# 7       241503             Long stay at The Breezy East "Leopard"    1017645
# 8       241508            Long stay at The Breezy East "Plumeria"    1017645
# 9       241510            Long stay at The Breezy East "Red Palm"    1017645
# 10      275343  Conveniently located City Room!( (Phone number...    1439258
# ...

# %%
data.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %% [markdown]
#  - `id` – room id
#  - `name` – room names
#  - `host_id` – host id
#  - `host_name` – host name
#  - `neighbourhood_group` – Singapore regions
#  - `neighbourhood` – specific place
#  - `latitude` – latitude
#  - `longitude` – longitude
#  - `room_type` – room type
#  - `price` – singapore dollar per night
#  - `minimum_nights` – minimum nights
#  - `number_of_reviews` – number of review
#  - `last_review` – last review
#  - `reviews_per_month` – I don't know exaclty
#  - `calculated_host_listings_count` – total room or house in host catalog on Airbnb
#  - `availability_365` – availability

# %%
print(data.shape)
print(data.columns)
# Out:
# (7907, 16)
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=7907, step=1)

# %%
data['price']
# Out:
# 0        83
# 1        81
# 2        69
# 3       206
# 4        94
# 5       104
# 6       208
# 7        50
# 8        54
# 9        42
# 10       44
# 11       40
# 12      417
# 13       65
# 14       44
# 15       40
# 16       31
# 17       49
# 18       81
# 19       60
# 20       60
# 21       56
# 22      104
# 23       37
# 24       53
# 25      276
# 26      167
# 27      100
# 28      208
# 29       26
#        ...
# 7877     35
# 7878     99
# 7879    110
# 7880     57
# 7881    300
# 7882     58
# 7883    437
# 7884    160
# 7885    200
# 7886     37
# 7887    129
# 7888     44
# 7889    139
# 7890    900
# 7891    110
# 7892    140
# 7893    100
# 7894    100
# 7895    100
# 7896     65
# 7897     40
# 7898    200
# 7899     33
# 7900     90
# 7901    100
# 7902    100
# 7903    550
# 7904     58
# 7905     56
# 7906     65
# Name: price, Length: 7907, dtype: int64

# %%
data['price'].dtype.name
# Out:
# 'int64'

# %%
type(data['price'][3])
# Out:
# numpy.int64

# %%
type(data['price'])
# Out:
# pandas.core.series.Series

# %%
data[['price', 'last_review']].head()
# Out:
#    price last_review
# 0     83  2013-10-21
# 1     81  2014-12-26
# 2     69  2015-10-01
# 3    206  2019-08-11
# 4     94  2019-07-28

# %%
data.describe()
# Out:
#                  id       host_id     latitude    longitude         price  \
# count  7.907000e+03  7.907000e+03  7907.000000  7907.000000   7907.000000
# mean   2.338862e+07  9.114481e+07     1.314192   103.848787    169.332996
# std    1.016416e+07  8.190910e+07     0.030577     0.043675    340.187599
# min    4.909100e+04  2.366600e+04     1.243870   103.646560      0.000000
# 25%    1.582180e+07  2.305808e+07     1.295795   103.835825     65.000000
# 50%    2.470627e+07  6.344891e+07     1.311030   103.849410    124.000000
# 75%    3.234850e+07  1.553811e+08     1.322110   103.872535    199.000000
# max    3.811276e+07  2.885676e+08     1.454590   103.973420  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count     7907.000000        7907.000000        5149.000000
# mean        17.510054          12.807386           1.043669
# std         42.094616          29.707746           1.285851
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (16, 16))
pass

# %% [markdown]
# Заметим, что зависимость долготы и широты можно рассмотреть как карту плотности отелей. Логично предположить, что большинство отелей находятся в центре города.

# %%
data.corr()
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.541770 -0.112042  -0.004701
# host_id                         0.541770  1.000000 -0.041237  -0.016341
# latitude                       -0.112042 -0.041237  1.000000  -0.034970
# longitude                      -0.004701 -0.016341 -0.034970   1.000000
# price                           0.049324  0.038802 -0.073990  -0.030436
# minimum_nights                 -0.083037 -0.089862  0.084924  -0.029208
# number_of_reviews              -0.341513 -0.175573 -0.015022   0.102109
# reviews_per_month               0.199958  0.169950 -0.029580   0.117578
# calculated_host_listings_count  0.245014 -0.063522 -0.149961   0.049416
# availability_365                0.113259  0.041840 -0.068740  -0.035727
#
#                                    price  minimum_nights  number_of_reviews  \
# id                              0.049324       -0.083037          -0.341513
# ...

# %%
plt.plot(data['price'], data['number_of_reviews'], 'o', alpha = 0.05)
plt.xlabel('price')
plt.ylabel('number_of_reviews')
plt.title('price vs number_of_reviews')
pass

# %%
plt.figure(figsize = (10, 6))


plt.scatter(data[data['price'] >  30]['latitude'],
            data[data['price'] >  30]['longitude'],
            alpha = 0.05,
            label = '>30',
            color = 'r')

plt.scatter(data[data['price'] <= 30]['latitude'],
            data[data['price'] <= 30]['longitude'],
            alpha = 0.15,
            label = '<=30',
            color = 'b')

plt.xlabel('latitude')
plt.xticks(range(18))
plt.xlim(1, 2)
plt.ylabel('longitude')
plt.legend()
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#                                                      name host_name  \
# count                                                7905      7907
# unique                                               7457      1833
# top     Luxury hostel with in-cabin locker - Single mixed       Jay
# freq                                                   13       290
#
#        neighbourhood_group neighbourhood        room_type last_review
# count                 7907          7907             7907        5149
# unique                   5            43                3        1001
# top         Central Region       Kallang  Entire home/apt  2019-08-12
# freq                  6309          1043             4132         152

# %%
data.describe(include = 'all')
# Out:
#                   id                                               name  \
# count   7.907000e+03                                               7905
# unique           NaN                                               7457
# top              NaN  Luxury hostel with in-cabin locker - Single mixed
# freq             NaN                                                 13
# mean    2.338862e+07                                                NaN
# std     1.016416e+07                                                NaN
# min     4.909100e+04                                                NaN
# 25%     1.582180e+07                                                NaN
# 50%     2.470627e+07                                                NaN
# 75%     3.234850e+07                                                NaN
# max     3.811276e+07                                                NaN
#
#              host_id host_name neighbourhood_group neighbourhood     latitude  \
# ...

# %%
data['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
data['neighbourhood'].unique()
# Out:
# array(['Woodlands', 'Bukit Timah', 'Tampines', 'Bedok', 'Bukit Merah',
#        'Newton', 'Geylang', 'River Valley', 'Jurong West', 'Rochor',
#        'Queenstown', 'Serangoon', 'Marine Parade', 'Pasir Ris',
#        'Toa Payoh', 'Outram', 'Punggol', 'Tanglin', 'Hougang', 'Kallang',
#        'Novena', 'Downtown Core', 'Bukit Panjang', 'Singapore River',
#        'Orchard', 'Ang Mo Kio', 'Bukit Batok', 'Museum', 'Sembawang',
#        'Choa Chu Kang', 'Central Water Catchment', 'Sengkang', 'Clementi',
#        'Jurong East', 'Bishan', 'Yishun', 'Mandai', 'Southern Islands',
#        'Sungei Kadut', 'Western Water Catchment', 'Tuas', 'Marina South',
#        'Lim Chu Kang'], dtype=object)

# %%
y = sorted(data['price'].unique())
x = range(len(y))
plt.plot(x,y)

# %% [markdown]
# ## Задача
# Предположить цену(> или < 200$).

# %% [markdown]
# # Готовим данные

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print()
print(numerical_columns)
# Out:
# ['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type', 'last_review']
#
# ['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# %%
data['price'] = np.array(['0' if i<200 else '1' for i in data['price']])
data = data.drop(('name'), axis = 1)
data = data.drop(('id'), axis = 1)
data = data.drop(('host_id'), axis = 1)
data = data.drop(('host_name'), axis = 1)
data = data.drop(('last_review'), axis = 1)
data = data.drop(('neighbourhood'), axis = 1)
data = data.drop(('availability_365'), axis = 1)
data = data.drop(('calculated_host_listings_count'), axis = 1)
data.head()
# Out:
#   neighbourhood_group  latitude  longitude     room_type price  \
# 0        North Region   1.44255  103.79580  Private room     0
# 1      Central Region   1.33235  103.78521  Private room     0
# 2        North Region   1.44246  103.79667  Private room     0
# 3         East Region   1.34541  103.95712  Private room     1
# 4         East Region   1.34567  103.95963  Private room     0
#
#    minimum_nights  number_of_reviews  reviews_per_month
# 0             180                  1               0.01
# 1              90                 18               0.28
# 2               6                 20               0.20
# 3               1                 14               0.15
# 4               1                 22               0.22

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print()
print(numerical_columns)
# Out:
# ['neighbourhood_group', 'room_type', 'price']
#
# ['latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'reviews_per_month']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# neighbourhood_group ['North Region' 'Central Region' 'East Region' 'West Region'
#  'North-East Region']
# room_type ['Private room' 'Entire home/apt' 'Shared room']
# price ['0' '1']

# %% [markdown]
# ## Обрабатываем пропущенные значения

# %%
data.median(axis = 0)
# Out:
# latitude               1.31103
# longitude            103.84941
# minimum_nights         3.00000
# number_of_reviews      2.00000
# reviews_per_month      0.55000
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# latitude             7907
# longitude            7907
# minimum_nights       7907
# number_of_reviews    7907
# reviews_per_month    7907
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# neighbourhood_group    7907
# room_type              7907
# price                  7907
# dtype: int64

# %%
print(data['neighbourhood_group'].describe(), '\n\n',
data['room_type'].describe())
# Out:
# count               7907
# unique                 5
# top       Central Region
# freq                6309
# Name: neighbourhood_group, dtype: object
#
#  count                7907
# unique                  3
# top       Entire home/apt
# freq                 4132
# Name: room_type, dtype: object

# %%
data['neighbourhood_group'] = data['neighbourhood_group'].fillna('Central Region')
data['room_type'] = data['room_type'].fillna('Entire home/apt')

# %%
data.describe(include = [object])
# Out:
#        neighbourhood_group        room_type price
# count                 7907             7907  7907
# unique                   5                3     2
# top         Central Region  Entire home/apt     0
# freq                  6309             4132  5939

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include = [object])
# Out:
#        neighbourhood_group        room_type price
# count                 7907             7907  7907
# unique                   5                3     2
# top         Central Region  Entire home/apt     0
# freq                  6309             4132  5939

# %% [markdown]
# ## Векторизация

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# ['price'] ['neighbourhood_group', 'room_type']

# %%
print(data['neighbourhood_group'].unique(), '\n',
data['room_type'].unique())
# Out:
# ['North Region' 'Central Region' 'East Region' 'West Region'
#  'North-East Region']
#  ['Private room' 'Entire home/apt' 'Shared room']

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])
print(data_nonbinary.columns)
# Out:
# Index(['neighbourhood_group_Central Region', 'neighbourhood_group_East Region',
#        'neighbourhood_group_North Region',
#        'neighbourhood_group_North-East Region',
#        'neighbourhood_group_West Region', 'room_type_Entire home/apt',
#        'room_type_Private room', 'room_type_Shared room'],
#       dtype='object')

# %% [markdown]
# ## Нормализация количественных признаков

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#           latitude    longitude  minimum_nights  number_of_reviews  \
# count  7907.000000  7907.000000     7907.000000        7907.000000
# mean      1.314192   103.848787       17.510054          12.807386
# std       0.030577     0.043675       42.094616          29.707746
# min       1.243870   103.646560        1.000000           0.000000
# 25%       1.295795   103.835825        1.000000           0.000000
# 50%       1.311030   103.849410        3.000000           2.000000
# 75%       1.322110   103.872535       10.000000          10.000000
# max       1.454590   103.973420     1000.000000         323.000000
#
#        reviews_per_month
# count        7907.000000
# mean            0.871475
# std             1.063948
# min             0.010000
# 25%             0.330000
# 50%             0.550000
# 75%             0.850000
# max            13.000000

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#            latitude     longitude  minimum_nights  number_of_reviews  \
# count  7.907000e+03  7.907000e+03     7907.000000       7.907000e+03
# mean   6.776351e-14  4.721528e-12        0.000000       2.875600e-17
# std    1.000000e+00  1.000000e+00        1.000000       1.000000e+00
# min   -2.299815e+00 -4.630317e+00       -0.392213      -4.311127e-01
# 25%   -6.016678e-01 -2.967960e-01       -0.392213      -4.311127e-01
# 50%   -1.034248e-01  1.425408e-02       -0.344701      -3.637902e-01
# 75%    2.589338e-01  5.437375e-01       -0.178409      -9.450013e-02
# max    4.591539e+00  2.853659e+00       23.340038       1.044147e+01
#
#        reviews_per_month
# count       7.907000e+03
# mean       -4.239353e-14
# std         1.000000e+00
# min        -8.096964e-01
# 25%        -5.089297e-01
# 50%        -3.021527e-01
# 75%        -2.018393e-02
# max         1.139955e+01

# %% [markdown]
# ## Соединяем все в одну таблицу

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)
print(data.shape)
#print data.columns
# Out:
# (7907, 14)

# %%
data.describe()
# Out:
#            latitude     longitude  minimum_nights  number_of_reviews  \
# count  7.907000e+03  7.907000e+03     7907.000000       7.907000e+03
# mean   6.776351e-14  4.721528e-12        0.000000       2.875600e-17
# std    1.000000e+00  1.000000e+00        1.000000       1.000000e+00
# min   -2.299815e+00 -4.630317e+00       -0.392213      -4.311127e-01
# 25%   -6.016678e-01 -2.967960e-01       -0.392213      -4.311127e-01
# 50%   -1.034248e-01  1.425408e-02       -0.344701      -3.637902e-01
# 75%    2.589338e-01  5.437375e-01       -0.178409      -9.450013e-02
# max    4.591539e+00  2.853659e+00       23.340038       1.044147e+01
#
#        reviews_per_month  neighbourhood_group_Central Region  \
# count       7.907000e+03                         7907.000000
# mean       -4.239353e-14                            0.797901
# std         1.000000e+00                            0.401591
# min        -8.096964e-01                            0.000000
# ...

# %% [markdown]
# # X и y

# %%
X = data.drop(('price'), axis = 1) # выбрасываем столбец 'class'
y = data['price']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['latitude', 'longitude', 'minimum_nights', 'number_of_reviews',
#        'reviews_per_month', 'neighbourhood_group_Central Region',
#        'neighbourhood_group_East Region', 'neighbourhood_group_North Region',
#        'neighbourhood_group_North-East Region',
#        'neighbourhood_group_West Region', 'room_type_Entire home/apt',
#        'room_type_Private room', 'room_type_Shared room'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (7907, 13)
# (7907,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 5534 2373

# %%
5534+2373
# Out:
# 7907

# %% [markdown]
# # $k$NN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# err_train 0.17130466208890496
# err_test 0.19174041297935104
# Out:
# 0.17130466208890496 0.19174041297935104

# %%
err_test = 1 - knn.score(X_test, y_test) # Другой способ

# %%
err_test
# Out:
# 0.19174041297935107

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[1685  132]
#  [ 323  233]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]])

# %% [markdown]
# ### Подбор параметров

# %%
# Долго!
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 20, 35, 50]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)

# best_cv_err 0.20473436935308997
# best_n_neighbors 10
# Out:
# 0.20473436935308997 10

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# err_train 0.17130466208890496
# err_test 0.19174041297935104
# Out:
# 0.17130466208890496 0.19174041297935104

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# err_train 0.24701843151427538
# err_test 0.22966708807416772
# Out:
# /home/egor/.local/lib/python3.5/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.24701843151427538 0.22966708807416772

# %% [markdown]
# ### Подбор параметров

# %%
from sklearn.model_selection import GridSearchCV
Cs = 10.**np.arange(-1, 2)
gamma_array = 10.**np.arange(-1, 2)
svc = SVC()
grid = GridSearchCV(svc, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C
print(best_cv_err, best_C)
# best_cv_err 0.20599927719551858
# best_C 1
# Out:
# /home/egor/.local/lib/python3.5/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.20599927719551858 1.0

# %%
svc = SVC(C = best_C).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)

# err_train 0.17130466208890496
# err_test 0.19174041297935104
# Out:
# /home/egor/.local/lib/python3.5/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.17130466208890496 0.19174041297935104

# %% [markdown]
# # Random Forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# err_train 0.0
# err_test 0.15760640539401602
# Out:
# 0.0 0.15760640539401602

# %% [markdown]
# ### Значимость признаков

# %%
a=[1,2,5,70,32,3,4,7,234, 3]
a[-1:3:-1]
# Out:
# [3, 234, 7, 4, 3, 32]

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'latitude' (0.263429)
#  2. feature 'longitude' (0.261052)
#  3. feature 'reviews_per_month' (0.108671)
#  4. feature 'minimum_nights' (0.105936)
#  5. feature 'room_type_Entire home/apt' (0.089408)
#  6. feature 'number_of_reviews' (0.085471)
#  7. feature 'room_type_Private room' (0.061473)
#  8. feature 'room_type_Shared room' (0.008843)
#  9. feature 'neighbourhood_group_Central Region' (0.007269)
# 10. feature 'neighbourhood_group_West Region' (0.002642)
# 11. feature 'neighbourhood_group_North-East Region' (0.002194)
# 12. feature 'neighbourhood_group_East Region' (0.002178)
# 13. feature 'neighbourhood_group_North Region' (0.001434)

# %%
feature_names[[1,0,1]]
# Out:
# Index(['longitude', 'latitude', 'longitude'], dtype='object')

# %%
d_first = 13
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 13)

# %% [markdown]
# # Extremely Randomized Trees

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)

# err_train 0.0
# err_test 0.16940581542351454
# Out:
# 0.0 0.16940581542351454

# %% [markdown]
# # AdaBoost

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# err_train 0.17058185760751718
# err_test 0.20185419300463547
# Out:
# 0.17058185760751718 0.20185419300463547

# %% [markdown]
# # GBT

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# err_train 0.059992771955186125
# err_test 0.18836915297092288
# Out:
# 0.059992771955186125 0.18836915297092288

# %% [markdown]
# # Нейронная сеть

# %%
from sklearn.neural_network import MLPClassifier

mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

print(1-mlp_model.score(X_train, y_train), 1-mlp_model.score(X_test, y_test))
# err_train 0.0
# err_test 0.16940581542351454
# Out:
# 0.20238525478857972 0.21660345554150862

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

plt.semilogx(alpha_arr, train_err, 'b-o', label = 'test')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'train')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print("min_train_err = ", min_train_err, "min_test_err = ", min_test_err)
alpha_opt = alpha_arr[test_err == min_test_err]
alpha_opt = alpha_opt[0]
print("alpha_opt = ", alpha_opt)


# min_train_err =  0.19714492229851824 
# min_test_err =  0.21238938053097345
# alpha_opt =  0.0031622776601683794
# Out:
# min_train_err =  0.19714492229851824 min_test_err =  0.21238938053097345
# alpha_opt =  0.0031622776601683794
# 0.21238938053097345 0.19714492229851824
